# %%
import cv2 
import skimage
import matplotlib.pyplot as plt

# %%
img = cv2.imread('robot1.jpg')
img.shape
# Out:
# (4592, 3448, 3)

# %%
# Image Type Conversion
    # Color Image to Grayscale
    # to Binary
# Geometric Transformations
    # Cropping
    # Scaling
    # Rotation
# Image Arithmetic / Brightness, Contrast Adjustments
    # Addition
    # Subraction
    # Multiplication
    # Division
    # Birghtness & Contrast Adjustment
    # Filteration -> Blurring/Sharpening
# Morphology
    # Structuring Element
    # Dilation
    # Erosion
    # Closing
    # Opening
    # Removing Small Holes
    # Removing Small Objects
    # Region Properties
# Feature Detection
    # Feature Detection -> Extraction
    # Feature Matching
# Out:
# '"\naddition \nsubstraction\nmultiplication\ndivision\nbrightness & constrast adjustments\n\nMarphology\nfeature detection\n'

# %%
plt.imshow(img[:,:,::-1])

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gray.shape
# Out:
# (4592, 3448)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
th, img_binary = cv2.threshold(img_gray, 70,255, cv2.THRESH_BINARY)
img_binary.shape
# Out:
# (4592, 3448)

# %%
plt.imshow(img_binary,  cmap='gray')

# %%
plt.imshow(img_binary[1000:5000,1000:2000,])

# %%
x,y,w,h = (50,150, 180, 140)
plt.subplot(1,3,1)
plt.imshow(img[y:y+h, x:x+w, ::-1])

x1,y1,x2,y2 = (50,150, 270, 210)
plt.subplot(1,3,2)
plt.imshow(img[y1:y2, x1:x2, ::-1])

y1,x1,y2,x2 = (50,150, 270, 210)
plt.subplot(1,3,3)
plt.imshow(img[y1:y2, x1:x2, ::-1])

# %%
img_large = cv2.resize(img, (1500,1500), interpolation=cv2.INTER_CUBIC)
img_large.shape
# Out:
# (1500, 1500, 3)

# %%
plt.imshow(img_large[:,:,::-1])

# %%
#scaling
img_large = cv2.resize(img, (1500,1500), interpolation=cv2.INTER_CUBIC)
img_large.shape
img_small = cv2.resize(img, (0,0), fx=.25,fy=.25, interpolation=cv2.INTER_CUBIC)
img_small.shape
# Out:
# (1148, 862, 3)

# %%
plt.imshow(img[:,:,::-1])

# %%
#Rotation
img_90 = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
plt.imshow(img_90[:,:,::-1])

# %%
rot_mat = cv2.getRotationMatrix2D(
   center =(img.shape[1]//2,img.shape[0]//2) ,angle =-30,scale =1.0)
img_x = cv2.warpAffine(img, rot_mat, dsize = (img.shape[1], img.shape[0] ),
                       flags = cv2.INTER_LINEAR)
plt.imshow(img_x[:,:,::-1]);plt.show()

#approach that we will follow or easy

img_x = skimage.transform.rotate(img, -30)
plt.imshow(img_x[:,:,::-1])

# %%
import numpy as np

# %%
# PIXEL HAS INTESITY VALUES.

plt.subplot(1,3,1)
plt.title("ORIGINAL IMAGE")
plt.imshow(img_x[:,:,::-1]); plt.axis("off")

# Addition
plt.subplot(1,3,2)
plt.title("BRIGHTENED IMAGE")
plt.imshow(cv2.add(img_x[:,:,::-1],20));plt.axis("off")
#we can even have used the img instead where we written 20, we can give input as image too #blending.

#Subtraction
plt.subplot(1,3,3)
plt.title("DARKENED IMAGE")
plt.imshow(cv2.subtract(img_x[:,:,::-1],20 ));plt.axis("off")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (-0.5, 3447.5, 4591.5, -0.5)

# %%
# constract :alpha is for constrast and beta is for brightness

img_cntbrt = cv2.convertScaleAbs(img, alpha=1.25,beta=0)
plt.imshow(img_cntbrt[:,:,::-1])

# %%
plt.subplot(1,2,1)
plt.imshow(img[:,:,::-1])
plt.subplot(1,2,2)
img_blur = cv2.medianBlur(img, 5)
plt.imshow(img_blur[:,:,::-1])
plt.show()

plt.subplot(1,2,1)
plt.imshow(img[:,:,::-1])
plt.subplot(1,2,2)
shrp_kernel = np.array([[0,-1,0],[-1,5,-1],[0,-1,0]])
img_sharp = cv2.filter2D(img, ddepth=-1, kernel=shrp_kernel)
plt.imshow(img_sharp[:,:,::-1])
