# %%
# !python -m pip install nltk
# !python -m pip install speechrecognition
# !python -m pip install pyttsx3
# Out:
# Collecting nltk
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: click in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from nltk) (8.1.6)
# Collecting joblib (from nltk)
#   Obtaining dependency information for joblib from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Obtaining dependency information for regex>=2021.8.3 from https://files.pythonhosted.org/packages/e6/7c/96a44dabe8577f43ac34e34d0ac098ee42390a06fee4cbe8b5317ecf2520/regex-2023.8.8-cp310-cp310-win_amd64.whl.metadata
#   Downloading regex-2023.8.8-cp310-cp310-win_amd64.whl.metadata (42 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      -------------------------------------  41.0/42.0 kB 960.0 kB/s eta 0:00:01
#      -------------------------------------- 42.0/42.0 kB 676.2 kB/s eta 0:00:00
# Collecting tqdm (from nltk)
#   Obtaining dependency information for tqdm from https://files.pythonhosted.org/packages/00/e5/f12a80907d0884e6dff9c16d0c0114d81b8cd07dc3ae54c5e962cc83037e/tqdm-4.66.1-py3-none-any.whl.metadata
#   Downloading tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB ? eta 0:00:00
# Requirement already satisfied: colorama in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from click->nltk) (0.4.6)
# Downloading regex-2023.8.8-cp310-cp310-win_amd64.whl (268 kB)
#    ---------------------------------------- 0.0/268.3 kB ? eta -:--:--
#    ---------------- ----------------------- 112.6/268.3 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  266.2/268.3 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 268.3/268.3 kB 2.8 MB/s eta 0:00:00
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ---------------------------------------- 0.0/302.2 kB ? eta -:--:--
#    ------------------ --------------------- 143.4/302.2 kB 4.3 MB/s eta 0:00:01
#    -------------------------------- ------- 245.8/302.2 kB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 302.2/302.2 kB 3.1 MB/s eta 0:00:00
# Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ---------------------------------------- 78.3/78.3 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: tqdm, regex, joblib, nltk
# Successfully installed joblib-1.3.2 nltk-3.8.1 regex-2023.8.8 tqdm-4.66.1
#   WARNING: The script tqdm.exe is installed in 'c:\Users\shubh\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script nltk.exe is installed in 'c:\Users\shubh\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Collecting speechrecognition
#   Downloading SpeechRecognition-3.10.0-py2.py3-none-any.whl (32.8 MB)
#      ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#      ---------------------------------------- 0.1/32.8 MB 1.7 MB/s eta 0:00:20
#      ---------------------------------------- 0.2/32.8 MB 1.5 MB/s eta 0:00:22
#      ---------------------------------------- 0.3/32.8 MB 2.3 MB/s eta 0:00:15
#      ---------------------------------------- 0.4/32.8 MB 2.2 MB/s eta 0:00:15
#       --------------------------------------- 0.6/32.8 MB 2.5 MB/s eta 0:00:13
#       --------------------------------------- 0.7/32.8 MB 2.8 MB/s eta 0:00:12
#      - -------------------------------------- 0.9/32.8 MB 3.0 MB/s eta 0:00:11
#      - -------------------------------------- 1.2/32.8 MB 3.3 MB/s eta 0:00:10
#      - -------------------------------------- 1.3/32.8 MB 3.2 MB/s eta 0:00:10
#      - -------------------------------------- 1.5/32.8 MB 3.2 MB/s eta 0:00:10
#      - -------------------------------------- 1.5/32.8 MB 3.1 MB/s eta 0:00:11
#      -- ------------------------------------- 1.8/32.8 MB 3.2 MB/s eta 0:00:10
#      -- ------------------------------------- 1.8/32.8 MB 3.1 MB/s eta 0:00:11
#      -- ------------------------------------- 2.0/32.8 MB 3.2 MB/s eta 0:00:10
#      -- ------------------------------------- 2.2/32.8 MB 3.1 MB/s eta 0:00:10
#      -- ------------------------------------- 2.4/32.8 MB 3.2 MB/s eta 0:00:10
#      --- ------------------------------------ 2.5/32.8 MB 3.3 MB/s eta 0:00:10
#      --- ------------------------------------ 2.7/32.8 MB 3.3 MB/s eta 0:00:10
#      --- ------------------------------------ 2.9/32.8 MB 3.4 MB/s eta 0:00:09
#      --- ------------------------------------ 3.0/32.8 MB 3.3 MB/s eta 0:00:10
#      --- ------------------------------------ 3.2/32.8 MB 3.3 MB/s eta 0:00:09
#      ---- ----------------------------------- 3.4/32.8 MB 3.4 MB/s eta 0:00:09
#      ---- ----------------------------------- 3.6/32.8 MB 3.4 MB/s eta 0:00:09
#      ---- -----------------------------------
8 MB 2.2 MB/s eta 0:00:01
#      -------------------------------------- - 31.3/32.8 MB 2.2 MB/s eta 0:00:01
#      -------------------------------------- - 31.4/32.8 MB 2.2 MB/s eta 0:00:01
#      -------------------------------------- - 31.5/32.8 MB 2.2 MB/s eta 0:00:01
#      -------------------------------------- - 31.6/32.8 MB 2.2 MB/s eta 0:00:01
#      -------------------------------------- - 31.7/32.8 MB 2.2 MB/s eta 0:00:01
#      -------------------------------------- - 31.8/32.8 MB 2.1 MB/s eta 0:00:01
#      -------------------------------------- - 31.9/32.8 MB 2.1 MB/s eta 0:00:01
#      -------------------------------------- - 32.0/32.8 MB 2.1 MB/s eta 0:00:01
#      ---------------------------------------  32.1/32.8 MB 2.1 MB/s eta 0:00:01
#      ---------------------------------------  32.2/32.8 MB 2.1 MB/s eta 0:00:01
#      ---------------------------------------  32.2/32.8 MB 2.1 MB/s eta 0:00:01
#      ---------------------------------------  32.3/32.8 MB 2.1 MB/s eta 0:00:01
#      ---------------------------------------  32.3/32.8 MB 2.1 MB/s eta 0:00:01
#      ---------------------------------------  32.4/32.8 MB 2.1 MB/s eta 0:00:01
#      ---------------------------------------  32.5/32.8 MB 2.1 MB/s eta 0:00:01
#      ---------------------------------------  32.6/32.8 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------  32.6/32.8 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------  32.7/32.8 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------  32.8/32.8 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------  32.8/32.8 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------  32.8/32.8 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------  32.8/32.8 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------- 32.8/32.8 MB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.26.0 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from speechrecognition) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26.0->speechrecognition) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26.0->speechrecognition) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26.0->speechrecognition) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shubh\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26.0->speechrecognition) (2023.7.22)
# Installing collected packages: speechrecognition
# Successfully installed speechrecognition-3.10.0
# Collecting pyttsx3
#   Using cached pyttsx3-2.90-py3-none-any.whl (39 kB)
# Collecting comtypes (from pyttsx3)
#   Obtaining dependency information for comtypes from https://files.pythonhosted.org/packages/c2/a7/fe4bd49b5c4afa7a7ed3852abda6909e48c00715e6a134e47055381113aa/comtypes-1.2.0-py2.py3-none-any.whl.metadata
#   Downloading comtypes-1.2.0-py2.py3-none-any.whl.metadata (3.7 kB)
# Collecting pypiwin32 (from pyttsx3)
#   Using cached pypiwin32-223-py3-none-any.whl (1.7 kB)
# Requirement already satisfied: pywin32 in c:\users\shubh\appdata\roaming\python\python310\site-packages (from pyttsx3) (306)
# Downloading comtypes-1.2.0-py2.py3-none-any.whl (184 kB)
#    ---------------------------------------- 0.0/184.3 kB ? eta -:--:--
#    --------------- ------------------------ 71.7/184.3 kB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 174.1/184.3 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 184.3/184.3 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: comtypes, pypiwin32, pyttsx3
# Successfully installed comtypes-1.2.0 pypiwin32-223 pyttsx3-2.90

# %%
import speech_recognition as sr
import nltk
import pyttsx3

# %%
import cv2
hog = cv2

# %%
import cv2
from time import sleep
hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
vid = cv2.VideoCapture(0)
while True:
    ack, img = vid.read()
    if ack:
        people, weights = hog.detectMultiScale(
            cv2.cvtColor(img, cv2.COLOR_BGR2GRAY),
            winStride=(15,15)
        )
        for x,y,w,h in people:
            cv2.rectangle(
                img, pt1=(x,y), pt2=(x+w,y+w),color=(0,0,255), thickness=5,
            )
        sleep(0.1)
        cv2.imshow('preview', img)
        if cv2.waitKey(delay=1) == ord('q'):
                        break
cv2.destroyAllWindows();cv2.waitKey(1)
vid.release()

# %%
# rule based chat-bot

# %%
import pyttsx3 # chat to voice coversion 
tts = pyttsx3.init()
tts.setProperty('rate', 150)

# %%
tts.say('hello iam speaking for you from your computer')
tts.runAndWait()

# %%
import speech_recognition as sr
import warnings; warnings.filterwarnings('ignore')
import webbrowser as web
rec = sr.Recognizer()
flag = False
while True:
  with sr.Microphone() as mic:
    print('Speak:')
    audio = rec.listen(mic,phrase_time_limit=3,timeout=5)
    try:
        text = rec.recognize_google(audio).lower()
        if flag == True:
            if 'search' in text:
                item = text.split('search')[-1].strip()
                flipkart_url = 'https://flipkart.com/search?q='
                amazon_url = 'https://amazon.in/s?k='
                web.open_new(flipkart_url + item)
                web.open_new_tab(amazon_url + item)
            flag = False
        if 'ok google' in text:
            flag = True
        elif 'stop' in text:
           break   
        print('you said', text) # for text 
        #tts.say(text) # for speech
        #tts.runAndWait()
    except Exception as err:
        print(err)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\speech_recognition\__init__.py:108, in Microphone.get_pyaudio()
#     107 try:
# --> 108     import pyaudio
#     109 except ImportError:
#
# ModuleNotFoundError: No module named 'pyaudio'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 7
#       5 flag = False
#       6 while True:
# ----> 7   with sr.Microphone() as mic:
#       8     print('Speak:')
#       9     audio = rec.listen(mic,phrase_time_limit=3,timeout=5)
#
# File c:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\speech_recognition\__init__.py:80, in Microphone.__init__(self, device_index, sample_rate, chunk_size)
#      77 assert isinstance(chunk_size, int) and chunk_size > 0, "Chunk size must be a positive integer"
#      79 # set up PyAudio
# ---> 80 self.pyaudio_module = self.get_pyaudio()
#      81 audio = self.pyaudio_module.PyAudio()
#      82 try:
#
# File c:\Users\shubh\AppData\Local\Programs\Python\Python310\lib\site-packages\speech_recognition\__init__.py:110, in Microphone.get_pyaudio()
#     108     import pyaudio
#     109 except ImportError:
# --> 110     raise AttributeError("Could not find PyAudio; check installation")
#     111 from distutils.version import LooseVersion
#     112 if LooseVersion(pyaudio.__version__) < LooseVersion("0.2.11"):
#
# AttributeError: Could not find PyAudio; check installation

# %%
# chatbot
from nltk.chat.util import Chat

# %%
q1 = r'(.*)your name(.*)'
a1 = ['my name is chatbot','I Am a chatbot']
q2 = r'kiya kuch ajj acha hoga'
a2 = ['haan','mujhe kiya pata','mrein kyo batau']
qa_pair = [
    [q1,a1],
    [q2,a2]
]
cb = Chat(qa_pair)

# %%
ques = input('enter ques').lower()
resp = cb.respond(ques)
print(resp)
# Out:
# I Am a chatbot

# %%
# regular expression
####################
#() capture and group
#. Any character new line nhi honi chiye
#* zero or more occurences
#|  or
#[]  set of charachters
#a-z 
#[a-c]
#[A-Z]
#0-9
# ^    starts with
# $  ends with
# ?      zero or more occurence
# +   one or more occurence
#  {}  exact number of occurence
#\w  only word charaters
#\ W not word characters

# %%
from nltk.chat.util import Chat
import speech_recognition as sr
import pyttsx3
q1 = r'(.*)your name(.*)'
a1 = ['my name is chatbot','I Am a chatbot']
q2 = r'kiya kuch ajj acha hoga'
a2 = ['haan','mujhe kiya pata','mrein kyo batau']
qa_pair = [
    [q1,a1],
    [q2,a2]
]
cb = Chat(qa_pair)
tts = pyttsx3.init()
rec = sr.Recognizer()

while True:
  with sr.Microphone() as mic:
    print('Speak:')
    audio = rec.listen(mic,phrase_time_limit=3,timeout=5)
    try:
        text = rec.recognize_google(audio).lower()
        if flag == True:
            if 'search' in text:
                item = text.split('search')[-1].strip()
                flipkart_url = 'https://flipkart.com/search?q='
                amazon_url = 'https://amazon.in/s?k='
                web.open_new(flipkart_url + item)
                web.open_new_tab(amazon_url + item)
            else:
               resp = cb.respond(text)
               if resp == None:
                  tts.say('sorry, I dont know')
               else:
                  tts.say(resp)
               tts.runAndWait()
            flag = False
        if 'ok google' in text:
            flag = True
        elif 'stop' in text:
           break   
        print('you said', text) # for text 
        #tts.say(text) # for speech
        #tts.runAndWait()
    except Exception as err:
        print(err)
# Out:
# Speak:
# you said ok google
# Speak:
# you said what's your name
# Speak:
